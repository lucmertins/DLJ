// %% [markdown]
// ## Executar apenas para instalação do kernel Java no Jupyter
// pip install jupyter
// git clone https://github.com/frankfliu/IJava.git
// cd IJava/
// ./gradlew installKernel  --warning-mode all
//
//
// Reiniciar vscode ou jupyter

// %%
System.out.print("teste")
// Out:
// teste

// %%
%maven org.knowm.xchart:xchart:3.8.8

import org.knowm.xchart.*;

double[] xData = new double[]{0.0, 1.0, 2.0};
double[] yData = new double[]{2.0, 1.0, 0.0};

XYChart chart = QuickChart.getChart("Sample Chart", "X", "Y", "y(x)", xData, yData);
BitmapEncoder.getBufferedImage(chart);
// Out:
// BufferedImage@3d52be66: type = 1 DirectColorModel: rmask=ff0000 gmask=ff00 bmask=ff amask=0 IntegerInterleavedRaster: width = 600 height = 400 #Bands = 3 xOff = 0 yOff = 0 dataOffset[0] 0
